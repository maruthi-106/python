# %% [markdown]
# <a href="https://colab.research.google.com/github/maruthi-106/python/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a code to reverse a string
in_string = input("enter a string\n")
revstring = in_string[::-1]
print(revstring)
# Out:
# enter a string
# abcd
# dcba

# %%
#Write a code to count the number of vowels in a string
in_string = input("enter a string\n")
vowels = "aeiou"
in_string = in_string.lower()
count = sum(in_string.count(i) for i in vowels)
print(count)
# Out:
# enter a string
# My Name Is Maruthi
# 6

# %%
#Write a code to check if a given string is a palindrome or not
in_string = input("enter a string\n")
in_string = in_string.lower()
revstring = in_string[::-1]
if in_string == revstring:
    print("palindrome")
else:
    print("not a palindrome")
# Out:
# enter a string
# Madam
# palindrome

# %%
# Write a code to check if two given strings are anagrams of each other
in_string1 = input("enter a string\n")
in_string2 = input("enter a string\n")
in_string1 = in_string1.lower()
in_string2 = in_string2.lower()
if (sorted(in_string1) == sorted(in_string2)):
    print("anagram")
else:
    print("not an anagram")
# Out:
# enter a string
# mart
# enter a string
# artm
# anagram

# %%
#Write a code to find all occurrences of a given substring within another string
in_string = input("enter a string\n")
sub_string = input("enter a substring\n")
in_string = in_string.lower()
sub_string = sub_string.lower()
count = in_string.count(sub_string)
print(count)
# Out:
# enter a string
# banana\
# enter a substring
# na
# 2

# %%
#Write a code to perform basic string compression using the counts of repeated characters
stringvalue = input("enter the string")
i=0
while i<len(stringvalue):
  if stringvalue[i]==stringvalue[i+1]:
    print(stringvalue[i])
    i+=1
# Out:
# a
# a

# %%
#Write a code to determine if a string has all unique characters
unic_char=[]
inp_str=input("enter string\n")
for i in inp_str:
  if i in unic_char:
    print("not unique")
    break
  else:
    unic_char.append(i)
if len(unic_char)==len(inp_str):
 print("unique")
# Out:
# enter string
# maruthi
# unique

# %%
#Write a code to convert a given string to uppercase or lowercase
in_str=input("enter string\n")
lwr=in_str.lower()
upr=in_str.upper()
print("lower string :",lwr)
print("upper string :",upr)
# Out:
# enter string
# Mahesh BAbu
# lower string : mahesh babu
# upper string : MAHESH BABU

# %%
# Write a code to count the number of words in a string
in_str= input("enter string\n")
in_str=in_str.split()
print("number of words in string :",len(in_str))
# Out:
# enter string
# i love my country
# number of words in string : 4

# %%
# Write a code to concatenate two strings without using the + operator
str1="ravi"
str2="teja"
str3= f"{str1} {str2}"
str3
# Out:
# 'ravi teja'

# %%
#Write a code to remove all occurrences of a specific element from a list
lis = ["k","a","r","t","h","i","k"]
lis1=[]
ele = input("enter element\n")
for  i in lis:
  if i != ele:
    lis1.append(i)
lis1
# Out:
# enter element
# k
# ['a', 'r', 't', 'h', 'i']

# %%
#Implement a code to find the second largest number in a given list of integer
lis=[1,11,9,2,14,4,5]
k=len(lis)
i=1
while i<len(lis):
  for  j in range(k):
    if lis[j]>lis[i]:
      t=lis[j]
      lis[j]=lis[i]
      lis[i]=t
  i=i+1
print("second largest number :",lis[-2])
# Out:
# second largest number : 11

# %%
#Create a code to count the occurrences of each element in a list and return a dictionary with elements as keys and their counts as values
lis=[1,2,3,1,2,3,2,3,3,4,5,0,4,6,9,6,8,6,9]
my_d={}
for i in lis:
  if i in my_d:
    my_d[i]+=1
  else:
    my_d[i]=1
my_d
# Out:
# {1: 2, 2: 3, 3: 4, 4: 2, 5: 1, 0: 1, 6: 3, 9: 2, 8: 1}

# %%
#Write a code to reverse a list in-place without using any built-in reverse functions
lis=[1,2,3,4,5,6,7]
lis1=[]
i=-1
j=len(lis)
while i>=-j:
  lis1.append(lis[i])
  i-=1
print(lis1)
# Out:
# [7, 6, 5, 4, 3, 2, 1]

# %%
#Implement a code to find and remove duplicates from a list while preserving the original order of elements
lis=[1,2,3,1,2,3,2,3,3,4,5,0,4,6,9,6,8,6,9]
lis1=[]
for i in lis:
  if i not in lis1:
    lis1.append(i)
lis1
# Out:
# [1, 2, 3, 4, 5, 0, 6, 9, 8]

# %%
#Create a code to check if a given list is sorted (either in ascending or descending order) or not
def is_sorted(lst):
    ascending = all(lst[i] <= lst[i + 1] for i in range(len(lst) - 1))
    descending = all(lst[i] >= lst[i + 1] for i in range(len(lst) - 1))
    return ascending or descending

# Example usage:
my_list = [1, 2, 3, 4, 5]
print(is_sorted(my_list))  # Output: True

my_list = [5, 4, 3, 2, 1]
print(is_sorted(my_list))  # Output: True

my_list = [1, 3, 2, 4, 5]
print(is_sorted(my_list))  # Output: False
# Out:
# True
# True
# False

# %%
#Write a code to merge two sorted lists into a single sorted list
def merge_sorted_lists(list1, list2):
    return sorted(list1 + list2)
list1 = [1, 3, 5, 7]
list2 = [2, 4, 6, 8]
result = merge_sorted_lists(list1, list2)
print("Merged Sorted List:", result)
# Out:
# Merged Sorted List: [1, 2, 3, 4, 5, 6, 7, 8]

# %%
#Implement a code to find the intersection of two given lists
def find_intersection(list1, list2):
    # Use set intersection to find common elements
    return list(set(list1) & set(list2))

list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
result = find_intersection(list1, list2)
print("Intersection of the two lists:", result)
# Out:
# Intersection of the two lists: [4, 5]

# %%
# Create a code to find the union of two lists without duplicates
list1 = [1, 2, 3, 4]
list2 = [3, 4, 5, 6]

# Use set to find the union and convert back to a list
union_list = list(set(list1) | set(list2))

print("Union of the two lists without duplicates:", union_list)

# %%
#Write a code to shuffle a given list randomly without using any built-in shuffle functions
import random

my_list = [1, 2, 3, 4, 5]

n = len(my_list)

for i in range(n):
    # Pick a random index from i (inclusive) to the end of the list
    rand_index = random.randint(i, n - 1)
    # Swap the elements at i and rand_index
    my_list[i], my_list[rand_index] = my_list[rand_index], my_list[i]

print("Shuffled list:", my_list)
# Out:
# Shuffled list: [4, 5, 2, 1, 3]

# %%
#Write a code that takes two tuples as input and returns a new tuple containing elements that are common to both input tuples
tuple1 = (1, 2, 3, 4, 5)
tuple2 = (4, 5, 6, 7, 8)

common_elements = tuple(set(tuple1) & set(tuple2))

print("Common elements tuple:", common_elements)

# %%
#Create a code that prompts the user to enter two sets of integers separated by commas. Then, print the intersection of these two sets

set1 = input("Enter the first set of integers (comma-separated): ")
set2 = input("Enter the second set of integers (comma-separated): ")

set1 = set(map(int, set1.split(',')))
set2 = set(map(int, set2.split(',')))

intersection = set1 & set2

print("The intersection of the two sets is:", intersection)
# Out:
# Enter the first set of integers (comma-separated): 1,7,8,4
# Enter the second set of integers (comma-separated): 4,4,7,9,6,9
# The intersection of the two sets is: {4, 7}

# %%
#Write a code to concatenate two tuples. The function should take two tuples as input and return a new tuple containing elements from both input tuples

tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)

concatenated_tuple = tuple1 + tuple2

print("Concatenated tuple:", concatenated_tuple)
# Out:
# Concatenated tuple: (1, 2, 3, 4, 5, 6)

# %%
#Develop a code that prompts the user to input two sets of strings. Then, print the elements that are present in the first set but not in the second set
set1 = input("Enter the first set of strings (comma-separated): ")
set2 = input("Enter the second set of strings (comma-separated): ")

set1 = set(set1.split(','))
set2 = set(set2.split(','))

difference = set1 - set2

print("Elements present in the first set but not in the second set:", difference)
# Out:
# Enter the first set of strings (comma-separated): a,s,d,f,g,h
# Enter the second set of strings (comma-separated): q,s,e,f,t,h
# Elements present in the first set but not in the second set: {'a', 'g', 'd'}

# %%
# Create a code that takes a tuple and two integers as input. The function should return a new tuple
#containing elements from the original tuple within the specified range of indices
original_tuple = (10, 20, 30, 40, 50, 60)
start_index = 2
end_index = 5

result = original_tuple[start_index:end_index]

print("Original tuple:", original_tuple)
print(f"Elements from index {start_index} to {end_index}:", result)
# Out:
# Original tuple: (10, 20, 30, 40, 50, 60)
# Elements from index 2 to 5: (30, 40, 50)

# %%
# Write a code that prompts the user to input two sets of characters. Then, print the union of these two sets
set1 = input("Enter the first set of characters (comma-separated): ")
set2 = input("Enter the second set of characters (comma-separated): ")

set1 = set(set1.split(','))
set2 = set(set2.split(','))

union_set = set1 | set2

print("The union of the two sets is:", union_set)
# Out:
# Enter the first set of characters (comma-separated): a,s,d,f,g
# Enter the second set of characters (comma-separated): q,s,e,f,t,h
# The union of the two sets is: {'a', 'e', 'f', 'q', 't', 'h', 's', 'g', 'd'}

# %%
#Develop a code that takes a tuple of integers as input. The function should return the maximum and
#minimum values from the tuple using tuple unpacking
def find_max_min(input_tuple):
    max_value = max(input_tuple)
    min_value = min(input_tuple)
    return max_value, min_value

input_tuple = (3, 5, 1, 9, 7)
max_val, min_val = find_max_min(input_tuple)

print("Original tuple:", input_tuple)
print("Maximum value:", max_val)
print("Minimum value:", min_val)
# Out:
# Original tuple: (3, 5, 1, 9, 7)
# Maximum value: 9
# Minimum value: 1

# %%
#Create a code that defines two sets of integers. Then, print the union, intersection, and difference of these
#two sets
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}

union_set = set1 | set2
intersection_set = set1 & set2
difference_set = set1 - set2

print("Set 1:", set1)
print("Set 2:", set2)
print("Union:", union_set)
print("Intersection:", intersection_set)
print("Difference (Set1 - Set2):", difference_set)
# Out:
# Set 1: {1, 2, 3, 4, 5}
# Set 2: {4, 5, 6, 7, 8}
# Union: {1, 2, 3, 4, 5, 6, 7, 8}
# Intersection: {4, 5}
# Difference (Set1 - Set2): {1, 2, 3}

# %%
#Write a code that takes a tuple and an element as input. The function should return the count of
#occurrences of the given element in the tuple
input_tuple = (1, 2, 3, 4, 2, 2, 5)
element = 2

count = input_tuple.count(element)

print(f"The element {element} occurs {count} times in the tuple.")
# Out:
# The element 2 occurs 3 times in the tuple.

# %%
#Develop a code that prompts the user to input two sets of strings. Then, print the symmetric difference of
#these two sets

set1 = input("Enter the first set of strings (comma-separated): ")
set2 = input("Enter the second set of strings (comma-separated): ")

set1 = set(set1.split(','))
set2 = set(set2.split(','))

symmetric_difference = set1 ^ set2

print("The symmetric difference of the two sets is:", symmetric_difference)
# Out:
# Enter the first set of strings (comma-separated): applr,banana,cherry
# Enter the second set of strings (comma-separated): banana,cherry,fox
# The symmetric difference of the two sets is: {'fox', 'applr'}

# %%
'''Write a code that takes a list of words as input and returns a dictionary where the keys are unique words
and the values are the frequencies of those words in the input list'''
words_list = input("Enter a list of words (space-separated): ").split()

word_frequencies = {}

for word in words_list:
    word_frequencies[word] = word_frequencies.get(word, 0) + 1

print("Word frequencies:", word_frequencies)
# Out:
# Enter a list of words (space-separated): apple apple apple banana banana orange
# Word frequencies: {'apple': 3, 'banana': 2, 'orange': 1}

# %%
'''Write a code that takes two dictionaries as input and merges them into a single dictionary. If there are
common keys, the values should be added together'''

dict1 = {'a': 10, 'b': 20, 'c': 30}
dict2 = {'b': 5, 'c': 15, 'd': 40}

merged_dict = dict1.copy()

for key, value in dict2.items():
    if key in merged_dict:
        merged_dict[key] += value
    else:
        merged_dict[key] = value

print("Merged Dictionary:", merged_dict)
# Out:
# Merged Dictionary: {'a': 10, 'b': 25, 'c': 45, 'd': 40}

# %%
'''Write a code to access a value in a nested dictionary. The function should take the dictionary and a list of
keys as input, and return the corresponding value. If any of the keys do not exist in the dictionary, the
function should return None&'''

def access_nested_value(nested_dict, keys):
    current = nested_dict
    for key in keys:
        if isinstance(current, dict) and key in current:
            current = current[key]
        else:
            return None
    return current
nested_dict = {
    'a': {
        'b': {
            'c': 42
        }
    }
}

keys = ['a', 'b', 'c']
result = access_nested_value(nested_dict, keys)
print("Value:", result)


keys = ['a', 'x', 'c']
result = access_nested_value(nested_dict, keys)
print("Value:", result)
# Out:
# Value: 42
# Value: None

# %%
'''Write a code that takes a dictionary as input and returns a sorted version of it based on the values. You
can choose whether to sort in ascending or descending order&'''
input_dict = {'a': 3, 'b': 1, 'c': 2, 'd': 5}

ascending = True

sorted_dict = dict(sorted(input_dict.items(), key=lambda item: item[1], reverse=not ascending))

print("Sorted Dictionary:", sorted_dict)
# Out:
# Sorted Dictionary: {'b': 1, 'c': 2, 'a': 3, 'd': 5}

# %%
'''Write a code that inverts a dictionary, swapping keys and values. Ensure that the inverted dictionary
correctly handles cases where multiple keys have the same value by storing the keys as a list in the
inverted dictionary'''

input_dict = {'a': 1, 'b': 2, 'c': 1, 'd': 3, 'e': 2}

inverted_dict = {}
for key, value in input_dict.items():
    if value in inverted_dict:
        inverted_dict[value].append(key)
    else:
        inverted_dict[value] = [key]

print("Inverted Dictionary:", inverted_dict)
# Out:
# Inverted Dictionary: {1: ['a', 'c'], 2: ['b', 'e'], 3: ['d']}
