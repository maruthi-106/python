# %% [markdown]
# <a href="https://colab.research.google.com/github/maruthi-106/python/blob/main/files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.How can you open a file for writing in Python and write a string to it
#open a file for writing
with open("example.txt","w") as F:
  F.write("i love you")

# %%
#2.Write a Python program to read the contents of a file and print each line
with open("example.txt","r") as F:
  for i in F:
    print(i.strip())
# Out:
# i love you

# %%
'''3.How would you handle a case where the file doesn't
exist while trying to open it for reading'''

try:
  with open("example2.txt","r") as F:
    print(F.read())
except FileNotFoundError:
  print("the file does not exist please cheak the file name and path")
# Out:
# the file does not exist please cheak the file name and path

# %%
#4.Write a Python script that reads from one file and writes its content to another file
with open("python.txt","r") as F:
  a=F.read()
with open("example.txt","w") as F:
  F.write(a)
with open("example.txt","r") as F:
  print(F.read())
# Out:
# In Python, text is represented as strings,
# and you can perform various operations on them,
# including reading, writing, and manipulating the text.
# Python also provides built-in functions and modules for working with files,
# which are essentially sequences of text

# %%
#How would you catch and handle division by zero error in Python
try:
  5/0
except ZeroDivisionError:
  print("division by zero is not possible")
# Out:
# division by zero is not possible

# %%
#Write a Python program that logs an error message to a log file when a division by zero exception occurs
import logging

# Configure the logging system
logging.basicConfig(filename='error_log.txt', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

try:
    # Code that might raise an exception
    numerator = 10
    denominator = 0
    result = numerator / denominator  # This will raise ZeroDivisionError
except ZeroDivisionError as e:
    # Log the error message to a file
    logging.error("Division by zero error occurred: %s", str(e))

    # Optional: print a user-friendly message
    print("Oops! Cannot divide by zero. Error logged.")
# Out:
# ERROR:root:Division by zero error occurred: division by zero
# Oops! Cannot divide by zero. Error logged.

# %%
#7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module
import logging

# Configure logging
logging.basicConfig(filename='app_log.txt', level=logging.DEBUG,
                    format='%(asctime)s - %(levelname)s - %(message)s')

# Log messages at different levels
logging.debug("This is a debug message.")     # For debugging
logging.info("This is an info message.")      # General info
logging.warning("This is a warning message.") # Warning, but not an error
logging.error("This is an error message.")    # An actual error occurred
logging.critical("This is a critical message.") # Serious error
# Out:
# WARNING:root:This is a warning message.
# ERROR:root:This is an error message.
# CRITICAL:root:This is a critical message.

# %%
#Write a program to handle a file opening error using exception handling
try:
  with open("new_txt","r") as F:
    F.read()
except Exception as e:
  print(e)
# Out:
# [Errno 2] No such file or directory: 'new_txt'

# %%
#How can you read a file line by line and store its content in a list in Python
lis=[]
with open("python.txt","r") as F:
  lis=F.readlines()
print(lis)
# Out:
# ['In Python, text is represented as strings, \n', 'and you can perform various operations on them, \n', 'including reading, writing, and manipulating the text.\n', 'Python also provides built-in functions and modules for working with files, \n', 'which are essentially sequences of text\n']

# %%
#How can you append data to an existing file in Python
with open("python.txt","a") as F:
  F.write("i am maruthi")
  F.write("i am from telangana")

# %%
#11. Write a Python program that uses a try-except block to handle an error when attempting to access a
#dictionary key that doesn't exist
dict={"key1": "maruthi","key2": "vamshi"}
try:
  dict["key3"]
except KeyError:
  print("the key doesn't exist")
# Out:
# the key doesn't exist

# %%
#Write a program that demonstrates using multiple except blocks
#to handle different types of exceptions
try:
  x=int(input("enter a number: "))
  y=10/x
  print("result:",y)
except ValueError:
  print("plrase enter a valid num")
except ZeroDivisionError:
  print("cannot divide by zero")
except Exception as e:
  print(f"unexpeceted error occured {str(e)}")
# Out:
# enter a number: 5
# result 2.0

# %%
#13. How would you check if a file exists before attempting to read it in Python
try:
  with open("example.txt","r") as F:
    content=F.read()
except FileNotFoundError:
  print("the file doesn't exist")

# %%
#14. Write a program that uses the logging module to log both informational and error messages
import logging
logging.basicConfig(level=logging.INFO,filename="app.log",filemode="w",
  format='%(asctime)s - %(levelname)s - %(message)s'
)
logger=logging.getLogger()
logger.info("this is an informational message")
logger.error("this is an error message")
# Out:
# ERROR:root:this is an error message

# %%
#15. Write a Python program that prints the content of a file and handles the case when the file is empty
try:
  with open("example.txt","r") as F:
    content=F.read()

    if content:
      print("file content: \n",content)
    else:
      print("the file is empty")
except Exception as e:
  print("an errr occured ",e)
# Out:
# the file is empty

# %%
pip install memory_profiler

# %%
#16. Demonstrate how to use memory profiling to check the memory usage of a small program
from memory_profiler import profile
import time

@profile
def meamory_hog():
  data=[]
  for j in range(5):
    chunk=[i for i in range(1000000)]
    data.append(chunk)
    time.sleep(1)
  return data

if __name__ == "__main__":
  meamory_hog

# %%
#Write a Python program to create and write a list of numbers to a file, one number per line
nums= [1,2,3,4,5]
with open("nums.txt","w") as F:
  for i in nums:
    F.write(str(i)+"\n")
with open("nums.txt","r") as F:
  print(F.read())
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#How would you implement a basic logging setup that logs to a file with rotation after 1MB
import logging
from logging.handlers import RotatingFileHandler as rfh

logger=logging.getLogger("my_logger")
logger.setLevel(logging.INFO)

handler=rfh(
    "app.log",
    maxBytes=1*1024*1024,
    backupCount=5
)

formatter=logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

logger.addHandler(handler)

for i in range(1000):
  logger.info(f"this is log message number {i}")
# Out:
# INFO:my_logger:this is log message number 0
# INFO:my_logger:this is log message number 1
# INFO:my_logger:this is log message number 2
# INFO:my_logger:this is log message number 3
# INFO:my_logger:this is log message number 4
# INFO:my_logger:this is log message number 5
# INFO:my_logger:this is log message number 6
# INFO:my_logger:this is log message number 7
# INFO:my_logger:this is log message number 8
# INFO:my_logger:this is log message number 9
# INFO:my_logger:this is log message number 10
# INFO:my_logger:this is log message number 11
# INFO:my_logger:this is log message number 12
# INFO:my_logger:this is log message number 13
# INFO:my_logger:this is log message number 14
# INFO:my_logger:this is log message number 15
# INFO:my_logger:this is log message number 16
# INFO:my_logger:this is log message number 17
# INFO:my_logger:this is log message number 18
# INFO:my_logger:this is log message number 19
# INFO:my_logger:this is log message number 20
# ...

# %%
#Write a program that handles both IndexError and KeyError using a try-except block
sequence = [1,2,3,4,5]
dictionary = {'name':'maruthi','age':19}
try:
  index = 10
  value = sequence[index]
  print(f"The value at index {index} is: {value}")
except IndexError:
  print("Error: Index is out of range.")

try:
  key = 'role'
  value = dictionary[key]
  print(f"The value for '{key} is: {value}")
except KeyError:
  print(f"Error: Key '{key}' not found in dictonary.")
# Out:
# Error: Index is out of range.
# Error: Key 'role' not found in dictonary.

# %%
#How would you open a file and read its contents using a context manager in Python
with open('example.txt', 'r') as file:
    for line in file:
        print(line.strip())

# %%
#Write a Python program that reads a file and prints the number of occurrences of a specific word
F= open("example.txt","r")
x=F.read()
x.count("are")
# Out:
# 1

# %%
#How can you check if a file is empty before attempting to read its contents
import os

def is_empty_file(filepath="example.txt"):
    try:
        return os.path.getsize(filepath) == 0
    except Exception as e:
        print(f"Error reading the file: {e}")
        return None

# %%
# Write a Python program that writes to a log file when an error occurs during file handling.
import os
from datetime import datetime

def handle_file(filepath):
    try:
        with open(filepath, "r") as f:
            content = f.read()
            print("File content:\n", content)
    except Exception as e:
        log_error(f"Error accessing file '{filepath}': {e}")

def log_error(message):
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    with open("error_log.txt", "a") as log_file:
        log_file.write(f"[{timestamp}] {message}\n")

# Example usage
handle_file("example.txt")  # Replace with a non-existent file name to test error logging
